# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df = pd.read_csv(r"C:\Users\Owner\Downloads\Statistics\CPSData.csv")
df = df.dropna().reset_index(drop=True)
df
# Out:
#        PeopleInHousehold   Region      State  MetroAreaCode  Age  \
# 0                      3    South    Alabama        13820.0   21
# 1                      3    South    Alabama        26620.0   52
# 2                      3    South    Alabama        26620.0   24
# 3                      3    South    Alabama        26620.0   26
# 4                      2    South    Alabama        33660.0   71
# ...                  ...      ...        ...            ...  ...
# 49391                  3  Midwest  Wisconsin        20740.0   47
# 49392                  3  Midwest  Wisconsin        20740.0   55
# 49393                  1  Midwest  Wisconsin        11540.0   48
# 49394                  2  Midwest  Wisconsin        20740.0   56
# 49395                  2  Midwest  Wisconsin        20740.0   59
#
#              Married     Sex                Education   Race  Hispanic  \
# 0      Never Married    Male              High school  Black         0
# ...

# %%
df_NY = df[(df['State']=='New York') & (df['EmploymentStatus']=='Unemployed')].reset_index(drop=True)
df_NY
# Out:
#      PeopleInHousehold     Region     State  MetroAreaCode  Age  \
# 0                    2  Northeast  New York        15380.0   26
# 1                    1  Northeast  New York        35620.0   54
# 2                    4  Northeast  New York        35620.0   41
# 3                    2  Northeast  New York        35620.0   34
# 4                    1  Northeast  New York        35620.0   52
# ..                 ...        ...       ...            ...  ...
# 154                  1  Northeast  New York        39100.0   53
# 155                  3  Northeast  New York        28740.0   43
# 156                  1  Northeast  New York        39100.0   49
# 157                  5  Northeast  New York        13780.0   35
# 158                  2  Northeast  New York        39100.0   29
#
#            Married     Sex                Education         Race  Hispanic  \
# 0    Never Married  Female        Bachelor's degree        White         0
# ...

# %%
df_TX = df[(df['State']=='Texas') & (df['EmploymentStatus']=='Unemployed')].reset_index(drop=True)
df_TX
# Out:
#      PeopleInHousehold Region  State  MetroAreaCode  Age        Married  \
# 0                    2  South  Texas        19100.0   28        Married
# 1                    2  South  Texas        19100.0   55  Never Married
# 2                    3  South  Texas        41700.0   24        Married
# 3                    2  South  Texas        19100.0   29  Never Married
# 4                    1  South  Texas        12420.0   25  Never Married
# ..                 ...    ...    ...            ...  ...            ...
# 164                  4  South  Texas        47020.0   55        Married
# 165                  4  South  Texas        47020.0   37  Never Married
# 166                  7  South  Texas        47020.0   19  Never Married
# 167                  1  South  Texas        47020.0   50       Divorced
# 168                  5  South  Texas        30980.0   33        Married
#
#         Sex                Education   Race  Hispanic  CountryOfBirthCode  \
# ...

# %%
print(df_NY.describe())
print("\n")
print(df_TX.describe())
# Out:
#        PeopleInHousehold  MetroAreaCode         Age    Hispanic  \
# count         159.000000     159.000000  159.000000  159.000000
# mean            3.018868   33754.339623   42.207547    0.201258
# std             1.655339    7474.333849   15.066131    0.402207
# min             1.000000   10580.000000   17.000000    0.000000
# 25%             2.000000   35620.000000   27.500000    0.000000
# 50%             3.000000   35620.000000   44.000000    0.000000
# 75%             4.000000   35620.000000   54.000000    0.000000
# max            12.000000   46540.000000   79.000000    1.000000
#
#        CountryOfBirthCode
# count          159.000000
# mean           142.270440
# std            129.401479
# min             57.000000
# 25%             57.000000
# 50%             57.000000
# 75%            224.000000
# max            555.000000
#
#
#        PeopleInHousehold  MetroAreaCode         Age    Hispanic  \
# count         169.000000     169.000000  169.000000  169.000000
# ...

# %%
df_rate = np.concatenate((df_NY['Age'].values, df_TX['Age'].values))
df_rate.mean()
# Out:
# 39.167682926829265

# %% [markdown]
# ### Hypotheses about the Difference in Two Sample Means

# %% [markdown]
# - Comparing Unemployment Rate in Wyoming County and Alabany County

# %% [markdown]
# #### H0: Sample Means are Equal
# #### H1: Sample Means are not Equal

# %%
a=np.var(df_NY['Age'])
b=np.var(df_TX['Age'])
print(a,b)
varianceValue = False
if a>b:
    c = a/b
elif b>a:
    c = b/a

if c<4:
    varianceValue = True

varianceValue
# Out:
# 225.56069775720906 198.59171597633133
# True

# %%
tstat,pval = stats.ttest_ind(a= df_NY['Age'].values,
                b= df_TX['Age'].values,
                equal_var=True)
print(tstat,pval)
# Out:
# 3.659262597052277 0.00029490691561204305

# %% [markdown]
# #### Confidence Interval of 95%

# %%
if pval <0.05:
    print("we reject null hypothesis")
else:
    print("we accept null hypothesis")
# Out:
# we reject null hypothesis
